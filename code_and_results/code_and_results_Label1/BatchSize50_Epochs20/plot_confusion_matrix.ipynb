# %%
# %reset -f

from sklearn.metrics import confusion_matrix
import pandas as pd

all_data = pd.read_csv('confusion_matrix1.csv', delimiter = ";", encoding = 'latin_1')

y_test=all_data['Label1']
y_pred=all_data['Label1_pred']

#Get the confusion matrix
cf_matrix = confusion_matrix(y_test, y_pred)

print(cf_matrix)
# Out:
# [[15 12  7 11]
#  [19 76 28 19]
#  [ 6  7 31  9]
#  [ 6 41 17 96]]

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

#ax = sns.heatmap(cf_matrix, annot=True, cmap='Blues')

ax = sns.heatmap(cf_matrix/np.sum(cf_matrix), annot=True, 
            fmt='.2%', cmap='Blues')

ax.set_title('Confusion Matrix Label 1 \n\n');
ax.set_xlabel('\nPredicted Category')
ax.set_ylabel('Actual Category ');

## Ticket labels - List must be in alphabetical order
ax.xaxis.set_ticklabels(['Not classifiable','Neutral', 'Positive', 'Negative'])
ax.yaxis.set_ticklabels(['Not classifiable','Neutral', 'Positive', 'Negative'])

## Display the visualization of the Confusion Matrix.
plt.show()

fig = ax.get_figure()
fig.savefig("plot1.pdf")

# %%
all_data = pd.read_csv('confusion_matrix.csv', delimiter = ";", encoding = 'latin_1')

y_test=all_data['Label2']
y_pred=all_data['Label2_pred']

#Get the confusion matrix
cf_matrix = confusion_matrix(y_test, y_pred)

print(cf_matrix)

# %%
#ax = sns.heatmap(cf_matrix, annot=True, cmap='Blues')

ax = sns.heatmap(cf_matrix/np.sum(cf_matrix), annot=True, 
            fmt='.2%', cmap='Blues')

ax.set_title('Confusion Matrix Label 2 \n\n');
ax.set_xlabel('\nPredicted Category')
ax.set_ylabel('Actual Category ');

## Ticket labels - List must be in alphabetical order
ax.xaxis.set_ticklabels(['Not classifiable','Scientific', 'Politic', 'Social','Symptoms'])
ax.yaxis.set_ticklabels(['Not classifiable','Scientific', 'Politic', 'Social','Symptoms'])

sns.set(rc = {'figure.figsize':(8,6)})

## Display the visualization of the Confusion Matrix.
plt.show()


fig = ax.get_figure()
fig.savefig("plot2.pdf")
